# %%
import pathlib
import shlex
import subprocess
from string import Template

import numpy as np
import pandas as pd
import polars as pl
import tqdm.notebook as tqdm

# %% [markdown]
# # Format simulated data
#
# ## Recode the chromosome in genotypes

# %%
(
    pl.read_csv("data/simulated-phenotypes/Genotypes.bim", separator="\t", has_header=False)
    .with_columns(pl.lit(1).alias("column_1"))
    .write_csv("data/simulated-phenotypes/Genotypes.bim", separator="\t", include_header=False)
)

# %% [markdown]
# ## Add names to the phenotype file

# %%
(
    pl.read_csv("data/simulated-phenotypes/Ysim_plink.txt", separator="\t", has_header=False)
    .rename({
        "column_1": "FID",
        "column_2": "IID",
        "column_3": "feature_01",
        "column_4": "feature_02",
        "column_5": "feature_03",
        "column_6": "feature_04",
        "column_7": "feature_05",
        "column_8": "feature_06",
        "column_9": "feature_07",
        "column_10": "feature_08",
        "column_11": "feature_09",
        "column_12": "feature_10",
    })
    .write_csv("data/simulated-phenotypes/Ysim_plink_names.txt", separator="\t")
)

# %% [markdown]
# ## Combine phenotypes and covariates into a single file
#
# Needed for SAIGE

# %%
(
    pl.read_csv("data/simulated-phenotypes/Ysim_plink_names.txt", separator="\t")
    .join(
        pl.read_csv("data/simulated-phenotypes/Covs_plink.txt", separator="\t"), 
        on=["FID", "IID"]
    )
    .write_csv("data/simulated-phenotypes/Ysim_saige.txt", separator="\t")
)

# %% [markdown]
# # Setup directories

# %%
pathlib.Path("data/grm/").mkdir(exist_ok=True)

pathlib.Path("data/projected-phenotypes/").mkdir(exist_ok=True)

gwas_root = pathlib.Path("data/gwas/")
gwas_root.mkdir(exist_ok=True)

gwas_methods = ["ols_univariate", "ols_multivariate", "fastgwa", "saige", "regenie"]
for gwas_method in gwas_methods:
    gwas_root.joinpath(gwas_method).mkdir(exist_ok=True)
    gwas_root.joinpath(gwas_method).joinpath("features").mkdir(exist_ok=True)
    gwas_root.joinpath(gwas_method).joinpath("projections").mkdir(exist_ok=True)

# %% [markdown]
# # Random linear combinations

# %%
np.random.seed(0)

n_features = 10
n_projections = 10

projection_matrix = np.random.normal(size=(n_features, n_projections))
projection_names = [f"projection_{i:03}" for i in range(1, n_projections + 1)]
feature_names = [f"feature_{i:02}" for i in range(1, n_features + 1)]
projection_df = pd.DataFrame(projection_matrix, columns=projection_names, index=feature_names)

feature_df = (
    pl.read_csv("data/simulated-phenotypes/Ysim_plink_names.txt", separator="\t")
    .to_pandas()
    .set_index(["FID", "IID"])
)

# Normalize the coefficients so that projections have unit variance
projection_df /= np.sqrt(np.diag(projection_df.T @ feature_df.cov() @ projection_df))

projected_df = feature_df @ projection_df

assert np.allclose(feature_df.mean(), 0)
assert np.allclose(projected_df.mean(), 0)

assert np.allclose(np.diag(feature_df.cov()), 1)
assert np.allclose(np.diag(projected_df.cov()), 1)

(
    projection_df
    .reset_index()
    .pipe(pl.DataFrame)
    .write_csv("data/projected-phenotypes/projection_matrix.tsv", separator="\t")
)

(
    projected_df
    .reset_index()
    .pipe(pl.DataFrame)
    .write_csv("data/projected-phenotypes/phenotypes.tsv", separator="\t")
)

# %%
(
    pl.read_csv("data/projected-phenotypes/phenotypes.tsv", separator="\t")
    .join(
        pl.read_csv("data/simulated-phenotypes/Covs_plink.txt", separator="\t"), 
        on=["FID", "IID"]
    )
    .write_csv("data/projected-phenotypes/phenotypes_saige.tsv", separator="\t")
)

# %% [markdown]
# # Make GRM
#
# ## GCTA

# %%
command = """
gcta64 \
    --bfile data/simulated-phenotypes/Genotypes \
    --chr 1 \
    --make-grm \
    --out data/grm/gcta
"""
result = subprocess.run(shlex.split(command))
# Out:
# *******************************************************************
# * GCTA (Genome-wide Complex Trait Analysis)
# * Version v1.94.1 Mac
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang jian.yang@westlake.edu.cn
# * MIT License
# *******************************************************************
# Analysis started at 16:46:09 PST on Wed Nov 13 2024.
# Hostname: awlpdcg540mz
#
# Options:
#
# --bfile data/simulated-phenotypes/Genotypes
# --chr 1
# --make-grm
# --out data/grm/gcta
#
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [data/simulated-phenotypes/Genotypes.fam]...
# 10000 individuals to be included from FAM file.
# 10000 individuals to be included. 0 males, 0 females, 10000 unknown.
# Reading PLINK BIM file from [data/simulated-phenotypes/Genotypes.bim]...
# 10000 SNPs to be included from BIM file(s).
# Computing the genetic relationship matrix (GRM) v2 ...
# Subset 1/1, no. subject 1-10000
#   10000 samples, 10000 markers, 50005000 GRM elements
# IDs for the GRM file have been saved in the file [data/grm/gcta.grm.id]
# Computing GRM...
#   100% finished in 2.4 sec
# 10000 SNPs have been processed.
#   Used 10000 valid SNPs.
# The GRM computation is completed.
# Saving GRM...
# GRM has been saved in the file [data/grm/gcta.grm.bin]
# Number of SNPs in each pair of individuals has been saved in the file [data/grm/gcta.grm.N.bin]
#
# Analysis finished at 16:46:12 PST on Wed Nov 13 2024
# Overall computational time: 2.91 sec.

# %%
command = """
gcta64 \
    --grm data/grm/gcta \
    --make-bK-sparse 0.05 \
    --out data/grm/gcta-sparse
"""
result = subprocess.run(shlex.split(command))
# Out:
# *******************************************************************
# * GCTA (Genome-wide Complex Trait Analysis)
# * Version v1.94.1 Mac
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang jian.yang@westlake.edu.cn
# * MIT License
# *******************************************************************
# Analysis started at 16:46:12 PST on Wed Nov 13 2024.
# Hostname: awlpdcg540mz
#
# Options:
#
# --grm data/grm/gcta
# --make-bK-sparse 0.05
# --out data/grm/gcta-sparse
#
# Pruning the GRM to a sparse matrix with a cutoff of 0.050000...
# Total number of parts to be processed: 2
#     Saving 10000 individual IDs
#     Processing part 1
# Saving the sparse GRM (10018 pairs) to [data/grm/gcta-sparse.grm.sp]
# finished generating a sparse GRM Success:
#
# Analysis finished at 16:46:12 PST on Wed Nov 13 2024
# Overall computational time: 0.18 sec.

# %% [markdown]
# # GWAS
#
# ## OLS univariate
#
# ### Features

# %%
command = """
plink2 \
    --bfile data/simulated-phenotypes/Genotypes \
    --pheno data/simulated-phenotypes/Ysim_plink.txt \
    --glm allow-no-covars \
    --out data/gwas/ols_univariate/features/result
"""
result = subprocess.run(shlex.split(command))
# Out:
# PLINK v2.00a6 M1 (18 Aug 2024)                 www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/gwas/ols_univariate/features/result.log.
# Options in effect:
#   --bfile data/simulated-phenotypes/Genotypes
#   --glm allow-no-covars
#   --out data/gwas/ols_univariate/features/result
#   --pheno data/simulated-phenotypes/Ysim_plink.txt
#
# Start time: Wed Nov 13 16:46:12 2024
# 65536 MiB RAM detected; reserving 32768 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 10000 samples (0 females, 0 males, 10000 ambiguous; 10000 founders) loaded from
# data/simulated-phenotypes/Genotypes.fam.
# 10000 variants loaded from data/simulated-phenotypes/Genotypes.bim.
# 10 quantitative phenotypes loaded.
# Calculating allele frequencies... done.
# --glm linear regression on quantitative phenotypes #1-10: done.
# Results written to data/gwas/ols_univariate/features/result.<phenotype
# name>.glm.linear .
# End time: Wed Nov 13 16:46:12 2024

# %% [markdown]
# ### Projections

# %%
command = """
plink2 \
    --bfile data/simulated-phenotypes/Genotypes \
    --pheno data/projected-phenotypes/phenotypes.tsv \
    --glm allow-no-covars \
    --out data/gwas/ols_univariate/projections/result
"""
result = subprocess.run(shlex.split(command))
# Out:
# PLINK v2.00a6 M1 (18 Aug 2024)                 www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/gwas/ols_univariate/projections/result.log.
# Options in effect:
#   --bfile data/simulated-phenotypes/Genotypes
#   --glm allow-no-covars
#   --out data/gwas/ols_univariate/projections/result
#   --pheno data/projected-phenotypes/phenotypes.tsv
#
# Start time: Wed Nov 13 16:46:12 2024
# 65536 MiB RAM detected; reserving 32768 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 10000 samples (0 females, 0 males, 10000 ambiguous; 10000 founders) loaded from
# data/simulated-phenotypes/Genotypes.fam.
# 10000 variants loaded from data/simulated-phenotypes/Genotypes.bim.
# 10 quantitative phenotypes loaded.
# Calculating allele frequencies... done.
# --glm linear regression on quantitative phenotypes #1-10: done.
# Results written to data/gwas/ols_univariate/projections/result.<phenotype
# name>.glm.linear .
# End time: Wed Nov 13 16:46:12 2024

# %% [markdown]
# ## OLS multivariate
#
# ### Features

# %%
command = """
plink2 \
    --bfile data/simulated-phenotypes/Genotypes \
    --pheno data/simulated-phenotypes/Ysim_plink.txt \
    --covar data/simulated-phenotypes/Covs_plink.txt \
    --glm hide-covar \
    --out data/gwas/ols_multivariate/features/result
"""
result = subprocess.run(shlex.split(command))
# Out:
# PLINK v2.00a6 M1 (18 Aug 2024)                 www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/gwas/ols_multivariate/features/result.log.
# Options in effect:
#   --bfile data/simulated-phenotypes/Genotypes
#   --covar data/simulated-phenotypes/Covs_plink.txt
#   --glm hide-covar
#   --out data/gwas/ols_multivariate/features/result
#   --pheno data/simulated-phenotypes/Ysim_plink.txt
#
# Start time: Wed Nov 13 16:46:12 2024
# 65536 MiB RAM detected; reserving 32768 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 10000 samples (0 females, 0 males, 10000 ambiguous; 10000 founders) loaded from
# data/simulated-phenotypes/Genotypes.fam.
# 10000 variants loaded from data/simulated-phenotypes/Genotypes.bim.
# 10 quantitative phenotypes loaded.
# 5 covariates loaded from data/simulated-phenotypes/Covs_plink.txt.
# Calculating allele frequencies... done.
# --glm linear regression on quantitative phenotypes #1-10: done.
# Results written to data/gwas/ols_multivariate/features/result.<phenotype
# name>.glm.linear .
# End time: Wed Nov 13 16:46:13 2024

# %% [markdown]
# ### Projections

# %%
command = """
plink2 \
    --bfile data/simulated-phenotypes/Genotypes \
    --pheno data/projected-phenotypes/phenotypes.tsv \
    --covar data/simulated-phenotypes/Covs_plink.txt \
    --glm hide-covar \
    --out data/gwas/ols_multivariate/projections/result
"""
result = subprocess.run(shlex.split(command))
# Out:
# PLINK v2.00a6 M1 (18 Aug 2024)                 www.cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/gwas/ols_multivariate/projections/result.log.
# Options in effect:
#   --bfile data/simulated-phenotypes/Genotypes
#   --covar data/simulated-phenotypes/Covs_plink.txt
#   --glm hide-covar
#   --out data/gwas/ols_multivariate/projections/result
#   --pheno data/projected-phenotypes/phenotypes.tsv
#
# Start time: Wed Nov 13 16:46:13 2024
# 65536 MiB RAM detected; reserving 32768 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 10000 samples (0 females, 0 males, 10000 ambiguous; 10000 founders) loaded from
# data/simulated-phenotypes/Genotypes.fam.
# 10000 variants loaded from data/simulated-phenotypes/Genotypes.bim.
# 10 quantitative phenotypes loaded.
# 5 covariates loaded from data/simulated-phenotypes/Covs_plink.txt.
# Calculating allele frequencies... done.
# --glm linear regression on quantitative phenotypes #1-10: done.
# Results written to data/gwas/ols_multivariate/projections/result.<phenotype
# name>.glm.linear .
# End time: Wed Nov 13 16:46:13 2024

# %% [markdown]
# ## Regenie
#
# ### Features

# %%
command = """
docker run \
    -v ./data:/data -w / \
    ghcr.io/rgcgithub/regenie/regenie:v4.0.gz regenie \
    --step 1 \
    --bed data/simulated-phenotypes/Genotypes \
    --covarFile data/simulated-phenotypes/Covs_plink.txt \
    --phenoFile data/simulated-phenotypes/Ysim_plink_names.txt \
    --bsize 100 \
    --qt \
    --out data/gwas/regenie/features/result
"""
result = subprocess.run(shlex.split(command))
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# Start time: Thu Nov 14 00:46:15 2024
#
#               |===========================|
#               |      REGENIE v4.0.gz      |
#               |===========================|
#
# Copyright (c) 2020-2024 Joelle Mbatchou, Andrey Ziyatdinov and Jonathan Marchini.
# Distributed under the MIT License.
# Compiled with Boost Iostream library.
# Compiled with HTSlib.
# Using Intel MKL with Eigen.
#
# Log of output saved in file : data/gwas/regenie/features/result.log
#
# Options in effect:
#   --step 1 \
#   --bed data/simulated-phenotypes/Genotypes \
#   --covarFile data/simulated-phenotypes/Covs_plink.txt \
#   --phenoFile data/simulated-phenotypes/Ysim_plink_names.txt \
#   --bsize 100 \
#   --qt \
#   --out data/gwas/regenie/features/result
#
# Fitting null model
#  * bim              : [data/simulated-phenotypes/Genotypes.bim] n_snps = 10000
#  * fam              : [data/simulated-phenotypes/Genotypes.fam] n_samples = 10000
#  * bed              : [data/simulated-phenotypes/Genotypes.bed]
#  * phenotypes       : [data/simulated-phenotypes/Ysim_plink_names.txt] n_pheno = 10
#    -keeping and mean-imputing missing observations (done for each trait)
#    -number of phenotyped individuals  = 10000
#  * covariates       : [data/simulated-phenotypes/Covs_plink.txt] n_cov = 5
#    -number of individuals with covariate data = 10000
#  * number of individuals used in analysis = 10000
#  * number of observations for each trait:
#    - 'feature_01': 10000 observations
#    - 'feature_02': 10000 observations
#    - 'feature_03': 10000 observations
#    - 'feature_04': 10000 observations
#    - 'feature_05': 10000 observations
#    - 'feature_06': 10000 observations
#    - 'feature_07': 10000 observations
#    - 'feature_08': 10000 observations
#    - 'feature_09': 10000 observations
#    - 'feature_10': 10000 observations
#    -residualizing and scaling phenotypes...done (1ms)
#  * # threads        : [15]
#  * block size       : [100]
#  * # blocks         : [100] for 10000 variants
#  * # CV folds       : [5]
#  * ridge data_l0    : [ 5 : 0.01 0.25 0.5 0.75 0.99 ]
#  * ridge data_l1    : [ 5 : 0.01 0.25 0.5 0.75 0.99 ]
#  * approximate memory usage : 416MB
#  * setting memory...done
#
# Chromosome 1
#  block [1] : 100 snps  (17ms)
#    -residualizing and scaling genotypes...done (4ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (22ms)
#  block [2] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (3ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (12ms)
#  block [3] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [4] : 100 snps  (23ms)
#    -residualizing and scaling genotypes...done (3ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [5] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [6] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [7] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [8] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [9] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [10] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [11] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [12] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [13] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [14] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [15] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [16] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [17] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [18] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [19] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [20] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [21] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [22] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [23] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [24] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [25] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [26] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [27] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [28] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [29] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [30] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [31] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [32] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [33] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [34] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [35] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [36] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [37] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [38] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [39] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [40] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [41] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [42] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [43] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [44] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [45] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [46] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [47] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [48] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (14ms)
#  block [49] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [50] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [51] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [52] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (14ms)
#  block [53] : 100 snps  (5ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [54] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [55] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [56] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [57] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [58] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [59] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (12ms)
#  block [60] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [61] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [62] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [63] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [64] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [65] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (32ms)
#  block [66] : 100 snps  (20ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [67] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [68] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [69] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [70] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [71] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [72] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [73] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [74] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [75] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [76] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [77] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [78] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [79] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [80] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [81] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [82] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [83] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [84] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [85] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [86] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [87] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [88] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [89] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [90] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [91] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [92] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [93] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [94] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [95] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [96] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [97] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [98] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [99] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [100] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#
#  Level 1 ridge...
#    -on phenotype 1 (feature_01)...done (403ms)
#    -on phenotype 2 (feature_02)...done (384ms)
#    -on phenotype 3 (feature_03)...done (375ms)
#    -on phenotype 4 (feature_04)...done (380ms)
#    -on phenotype 5 (feature_05)...done (375ms)
#    -on phenotype 6 (feature_06)...done (377ms)
#    -on phenotype 7 (feature_07)...done (374ms)
#    -on phenotype 8 (feature_08)...done (374ms)
#    -on phenotype 9 (feature_09)...done (375ms)
#    -on phenotype 10 (feature_10)...done (371ms)
#
# Output
# ------
# phenotype 1 (feature_01) :
#   0.01  : Rsq = 0.0189239, MSE = 0.98332
#   0.25  : Rsq = 0.018925, MSE = 0.982424
#   0.5   : Rsq = 0.019874, MSE = 0.981636
#   0.75  : Rsq = 0.0217418, MSE = 0.979644<- min value
#   0.99  : Rsq = 0.0237075, MSE = 0.982091
#   * making predictions...writing LOCO predictions...done (66ms)
#
# phenotype 2 (feature_02) :
#   0.01  : Rsq = 0.236413, MSE = 0.83006
#   0.25  : Rsq = 0.236105, MSE = 0.763451
#   0.5   : Rsq = 0.236615, MSE = 0.763177
#   0.75  : Rsq = 0.237428, MSE = 0.762528<- min value
#   0.99  : Rsq = 0.233683, MSE = 0.767384
#   * making predictions...writing LOCO predictions...done (63ms)
#
# phenotype 3 (feature_03) :
#   0.01  : Rsq = 0.249361, MSE = 0.818247
#   0.25  : Rsq = 0.247927, MSE = 0.751636<- min value
#   0.5   : Rsq = 0.248057, MSE = 0.751745
#   0.75  : Rsq = 0.248209, MSE = 0.751775
#   0.99  : Rsq = 0.243674, MSE = 0.757272
#   * making predictions...writing LOCO predictions...done (63ms)
#
# phenotype 4 (feature_04) :
#   0.01  : Rsq = 0.350888, MSE = 0.752361
#   0.25  : Rsq = 0.351077, MSE = 0.648573<- min value
#   0.5   : Rsq = 0.351014, MSE = 0.648674
#   0.75  : Rsq = 0.35067, MSE = 0.649166
#   0.99  : Rsq = 0.34427, MSE = 0.656292
#   * making predictions...writing LOCO predictions...done (63ms)
#
# phenotype 5 (feature_05) :
#   0.01  : Rsq = 0.329195, MSE = 0.763748
#   0.25  : Rsq = 0.328711, MSE = 0.670909<- min value
#   0.5   : Rsq = 0.328744, MSE = 0.670938
#   0.75  : Rsq = 0.328612, MSE = 0.671209
#   0.99  : Rsq = 0.322607, MSE = 0.677984
#   * making predictions...writing LOCO predictions...done (64ms)
#
# phenotype 6 (feature_06) :
#   0.01  : Rsq = 0.0706465, MSE = 0.945975
#   0.25  : Rsq = 0.0705834, MSE = 0.929446
#   0.5   : Rsq = 0.0713099, MSE = 0.929058
#   0.75  : Rsq = 0.0726141, MSE = 0.927867<- min value
#   0.99  : Rsq = 0.071595, MSE = 0.931089
#   * making predictions...writing LOCO predictions...done (63ms)
#
# phenotype 7 (feature_07) :
#   0.01  : Rsq = 0.137263, MSE = 0.898991
#   0.25  : Rsq = 0.136705, MSE = 0.86301
#   0.5   : Rsq = 0.137442, MSE = 0.862632
#   0.75  : Rsq = 0.138717, MSE = 0.86154<- min value
#   0.99  : Rsq = 0.135935, MSE = 0.86643
#   * making predictions...writing LOCO predictions...done (64ms)
#
# phenotype 8 (feature_08) :
#   0.01  : Rsq = 0.285399, MSE = 0.798451
#   0.25  : Rsq = 0.286135, MSE = 0.713453
#   0.5   : Rsq = 0.286542, MSE = 0.713117
#   0.75  : Rsq = 0.287162, MSE = 0.712617<- min value
#   0.99  : Rsq = 0.283724, MSE = 0.716718
#   * making predictions...writing LOCO predictions...done (63ms)
#
# phenotype 9 (feature_09) :
#   0.01  : Rsq = 0.119667, MSE = 0.911429
#   0.25  : Rsq = 0.118679, MSE = 0.881071<- min value
#   0.5   : Rsq = 0.118613, MSE = 0.881538
#   0.75  : Rsq = 0.118262, MSE = 0.882173
#   0.99  : Rsq = 0.111919, MSE = 0.890744
#   * making predictions...writing LOCO predictions...done (63ms)
#
# phenotype 10 (feature_10) :
#   0.01  : Rsq = 0.202909, MSE = 0.853554
#   0.25  : Rsq = 0.202312, MSE = 0.797249
#   0.5   : Rsq = 0.202552, MSE = 0.797286
#   0.75  : Rsq = 0.202845, MSE = 0.797188<- min value
#   0.99  : Rsq = 0.198132, MSE = 0.803202
#   * making predictions...writing LOCO predictions...done (63ms)
#
# List of blup files written to: [data/gwas/regenie/features/result_pred.list]
#
# Elapsed time : 7.96641s
# End time: Thu Nov 14 00:46:23 2024

# %%
command = """
docker run \
    -v ./data:/data -w / \
    ghcr.io/rgcgithub/regenie/regenie:v4.0.gz regenie \
    --step 2 \
    --bed data/simulated-phenotypes/Genotypes \
    --covarFile data/simulated-phenotypes/Covs_plink.txt \
    --phenoFile data/simulated-phenotypes/Ysim_plink_names.txt \
    --bsize 100 \
    --qt \
    --pred data/gwas/regenie/features/result_pred.list \
    --out data/gwas/regenie/features/result
"""
result = subprocess.run(shlex.split(command))
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# Start time: Thu Nov 14 00:46:23 2024
#
#               |===========================|
#               |      REGENIE v4.0.gz      |
#               |===========================|
#
# Copyright (c) 2020-2024 Joelle Mbatchou, Andrey Ziyatdinov and Jonathan Marchini.
# Distributed under the MIT License.
# Compiled with Boost Iostream library.
# Compiled with HTSlib.
# Using Intel MKL with Eigen.
#
# Log of output saved in file : data/gwas/regenie/features/result.log
#
# Options in effect:
#   --step 2 \
#   --bed data/simulated-phenotypes/Genotypes \
#   --covarFile data/simulated-phenotypes/Covs_plink.txt \
#   --phenoFile data/simulated-phenotypes/Ysim_plink_names.txt \
#   --bsize 100 \
#   --qt \
#   --pred data/gwas/regenie/features/result_pred.list \
#   --out data/gwas/regenie/features/result
#
# Association testing mode with fast multithreading using OpenMP
#  * bim              : [data/simulated-phenotypes/Genotypes.bim] n_snps = 10000
#  * fam              : [data/simulated-phenotypes/Genotypes.fam] n_samples = 10000
#  * bed              : [data/simulated-phenotypes/Genotypes.bed]
#  * phenotypes       : [data/simulated-phenotypes/Ysim_plink_names.txt] n_pheno = 10
#    -number of phenotyped individuals  = 10000
#  * covariates       : [data/simulated-phenotypes/Covs_plink.txt] n_cov = 5
#    -number of individuals with covariate data = 10000
#  * number of individuals used in analysis = 10000
#  * number of observations for each trait:
#    - 'feature_01': 10000 observations
#    - 'feature_02': 10000 observations
#    - 'feature_03': 10000 observations
#    - 'feature_04': 10000 observations
#    - 'feature_05': 10000 observations
#    - 'feature_06': 10000 observations
#    - 'feature_07': 10000 observations
#    - 'feature_08': 10000 observations
#    - 'feature_09': 10000 observations
#    - 'feature_10': 10000 observations
#  * LOCO predictions : [data/gwas/regenie/features/result_pred.list]
#    -file [/data/gwas/regenie/features/result_1.loco] for phenotype 'feature_01'
#    -file [/data/gwas/regenie/features/result_2.loco] for phenotype 'feature_02'
#    -file [/data/gwas/regenie/features/result_3.loco] for phenotype 'feature_03'
#    -file [/data/gwas/regenie/features/result_4.loco] for phenotype 'feature_04'
#    -file [/data/gwas/regenie/features/result_5.loco] for phenotype 'feature_05'
#    -file [/data/gwas/regenie/features/result_6.loco] for phenotype 'feature_06'
#    -file [/data/gwas/regenie/features/result_7.loco] for phenotype 'feature_07'
#    -file [/data/gwas/regenie/features/result_8.loco] for phenotype 'feature_08'
#    -file [/data/gwas/regenie/features/result_9.loco] for phenotype 'feature_09'
#    -file [/data/gwas/regenie/features/result_10.loco] for phenotype 'feature_10'
#    -residualizing and scaling phenotypes...done (1ms)
#  * # threads        : [15]
#  * block size       : [100]
#  * # blocks         : [100]
#  * approximate memory usage : 22MB
#  * using minimum MAC of 5 (variants with lower MAC are ignored)
#
# Chromosome 1 [100 blocks in total]
#    -reading loco predictions for the chromosome...done (201ms)
#  block [1/100] : done (75ms)
#  block [2/100] : done (7ms)
#  block [3/100] : done (5ms)
#  block [4/100] : done (5ms)
#  block [5/100] : done (6ms)
#  block [6/100] : done (5ms)
#  block [7/100] : done (5ms)
#  block [8/100] : done (5ms)
#  block [9/100] : done (5ms)
#  block [10/100] : done (5ms)
#  block [11/100] : done (5ms)
#  block [12/100] : done (5ms)
#  block [13/100] : done (5ms)
#  block [14/100] : done (5ms)
#  block [15/100] : done (6ms)
#  block [16/100] : done (5ms)
#  block [17/100] : done (5ms)
#  block [18/100] : done (5ms)
#  block [19/100] : done (5ms)
#  block [20/100] : done (5ms)
#  block [21/100] : done (5ms)
#  block [22/100] : done (5ms)
#  block [23/100] : done (5ms)
#  block [24/100] : done (5ms)
#  block [25/100] : done (5ms)
#  block [26/100] : done (5ms)
#  block [27/100] : done (5ms)
#  block [28/100] : done (5ms)
#  block [29/100] : done (5ms)
#  block [30/100] : done (5ms)
#  block [31/100] : done (5ms)
#  block [32/100] : done (5ms)
#  block [33/100] : done (5ms)
#  block [34/100] : done (5ms)
#  block [35/100] : done (5ms)
#  block [36/100] : done (5ms)
#  block [37/100] : done (5ms)
#  block [38/100] : done (5ms)
#  block [39/100] : done (5ms)
#  block [40/100] : done (5ms)
#  block [41/100] : done (5ms)
#  block [42/100] : done (5ms)
#  block [43/100] : done (5ms)
#  block [44/100] : done (5ms)
#  block [45/100] : done (5ms)
#  block [46/100] : done (5ms)
#  block [47/100] : done (5ms)
#  block [48/100] : done (5ms)
#  block [49/100] : done (5ms)
#  block [50/100] : done (5ms)
#  block [51/100] : done (5ms)
#  block [52/100] : done (5ms)
#  block [53/100] : done (5ms)
#  block [54/100] : done (5ms)
#  block [55/100] : done (5ms)
#  block [56/100] : done (5ms)
#  block [57/100] : done (5ms)
#  block [58/100] : done (5ms)
#  block [59/100] : done (5ms)
#  block [60/100] : done (5ms)
#  block [61/100] : done (5ms)
#  block [62/100] : done (5ms)
#  block [63/100] : done (5ms)
#  block [64/100] : done (5ms)
#  block [65/100] : done (5ms)
#  block [66/100] : done (5ms)
#  block [67/100] : done (5ms)
#  block [68/100] : done (5ms)
#  block [69/100] : done (5ms)
#  block [70/100] : done (5ms)
#  block [71/100] : done (5ms)
#  block [72/100] : done (5ms)
#  block [73/100] : done (5ms)
#  block [74/100] : done (5ms)
#  block [75/100] : done (5ms)
#  block [76/100] : done (5ms)
#  block [77/100] : done (5ms)
#  block [78/100] : done (5ms)
#  block [79/100] : done (6ms)
#  block [80/100] : done (5ms)
#  block [81/100] : done (5ms)
#  block [82/100] : done (5ms)
#  block [83/100] : done (5ms)
#  block [84/100] : done (5ms)
#  block [85/100] : done (5ms)
#  block [86/100] : done (5ms)
#  block [87/100] : done (5ms)
#  block [88/100] : done (5ms)
#  block [89/100] : done (5ms)
#  block [90/100] : done (5ms)
#  block [91/100] : done (5ms)
#  block [92/100] : done (5ms)
#  block [93/100] : done (5ms)
#  block [94/100] : done (5ms)
#  block [95/100] : done (5ms)
#  block [96/100] : done (6ms)
#  block [97/100] : done (5ms)
#  block [98/100] : done (5ms)
#  block [99/100] : done (5ms)
#  block [100/100] : done (5ms)
#
# Association results stored separately for each trait in files :
# * [data/gwas/regenie/features/result_feature_01.regenie]
# * [data/gwas/regenie/features/result_feature_02.regenie]
# * [data/gwas/regenie/features/result_feature_03.regenie]
# * [data/gwas/regenie/features/result_feature_04.regenie]
# * [data/gwas/regenie/features/result_feature_05.regenie]
# * [data/gwas/regenie/features/result_feature_06.regenie]
# * [data/gwas/regenie/features/result_feature_07.regenie]
# * [data/gwas/regenie/features/result_feature_08.regenie]
# * [data/gwas/regenie/features/result_feature_09.regenie]
# * [data/gwas/regenie/features/result_feature_10.regenie]
#
# Number of ignored tests due to low MAC : 0
#
# Elapsed time : 1.56612s
# End time: Thu Nov 14 00:46:25 2024

# %% [markdown]
# ### Projections

# %%
command = """
docker run \
    -v ./data:/data -w / \
    ghcr.io/rgcgithub/regenie/regenie:v4.0.gz regenie \
    --step 1 \
    --bed data/simulated-phenotypes/Genotypes \
    --covarFile data/simulated-phenotypes/Covs_plink.txt \
    --phenoFile data/projected-phenotypes/phenotypes.tsv \
    --bsize 100 \
    --qt \
    --out data/gwas/regenie/projections/result
"""
result = subprocess.run(shlex.split(command))
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# Start time: Thu Nov 14 00:46:25 2024
#
#               |===========================|
#               |      REGENIE v4.0.gz      |
#               |===========================|
#
# Copyright (c) 2020-2024 Joelle Mbatchou, Andrey Ziyatdinov and Jonathan Marchini.
# Distributed under the MIT License.
# Compiled with Boost Iostream library.
# Compiled with HTSlib.
# Using Intel MKL with Eigen.
#
# Log of output saved in file : data/gwas/regenie/projections/result.log
#
# Options in effect:
#   --step 1 \
#   --bed data/simulated-phenotypes/Genotypes \
#   --covarFile data/simulated-phenotypes/Covs_plink.txt \
#   --phenoFile data/projected-phenotypes/phenotypes.tsv \
#   --bsize 100 \
#   --qt \
#   --out data/gwas/regenie/projections/result
#
# Fitting null model
#  * bim              : [data/simulated-phenotypes/Genotypes.bim] n_snps = 10000
#  * fam              : [data/simulated-phenotypes/Genotypes.fam] n_samples = 10000
#  * bed              : [data/simulated-phenotypes/Genotypes.bed]
#  * phenotypes       : [data/projected-phenotypes/phenotypes.tsv] n_pheno = 10
#    -keeping and mean-imputing missing observations (done for each trait)
#    -number of phenotyped individuals  = 10000
#  * covariates       : [data/simulated-phenotypes/Covs_plink.txt] n_cov = 5
#    -number of individuals with covariate data = 10000
#  * number of individuals used in analysis = 10000
#  * number of observations for each trait:
#    - 'projection_001': 10000 observations
#    - 'projection_002': 10000 observations
#    - 'projection_003': 10000 observations
#    - 'projection_004': 10000 observations
#    - 'projection_005': 10000 observations
#    - 'projection_006': 10000 observations
#    - 'projection_007': 10000 observations
#    - 'projection_008': 10000 observations
#    - 'projection_009': 10000 observations
#    - 'projection_010': 10000 observations
#    -residualizing and scaling phenotypes...done (1ms)
#  * # threads        : [15]
#  * block size       : [100]
#  * # blocks         : [100] for 10000 variants
#  * # CV folds       : [5]
#  * ridge data_l0    : [ 5 : 0.01 0.25 0.5 0.75 0.99 ]
#  * ridge data_l1    : [ 5 : 0.01 0.25 0.5 0.75 0.99 ]
#  * approximate memory usage : 416MB
#  * setting memory...done
#
# Chromosome 1
#  block [1] : 100 snps  (18ms)
#    -residualizing and scaling genotypes...done (3ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (22ms)
#  block [2] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [3] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (12ms)
#  block [4] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [5] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [6] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [7] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [8] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [9] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [10] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [11] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [12] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [13] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [14] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [15] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [16] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [17] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [18] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [19] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [20] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [21] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [22] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [23] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [24] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [25] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [26] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [27] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [28] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [29] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [30] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [31] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [32] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [33] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [34] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [35] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [36] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [37] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [38] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [39] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [40] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [41] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [42] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [43] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [44] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [45] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [46] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [47] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [48] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [49] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [50] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [51] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [52] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [53] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (3ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [54] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [55] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [56] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [57] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [58] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [59] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [60] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [61] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [62] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (12ms)
#  block [63] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [64] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (17ms)
#  block [65] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [66] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [67] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (12ms)
#  block [68] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [69] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (15ms)
#    -calc level 0 ridge...done (12ms)
#  block [70] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [71] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [72] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (12ms)
#  block [73] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (12ms)
#  block [74] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [75] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [76] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [77] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (12ms)
#  block [78] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [79] : 100 snps  (4ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [80] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [81] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [82] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [83] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [84] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [85] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (13ms)
#  block [86] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [87] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (11ms)
#  block [88] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [89] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [90] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [91] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [92] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [93] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [94] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [95] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [96] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [97] : 100 snps  (3ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (11ms)
#    -calc level 0 ridge...done (13ms)
#  block [98] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (12ms)
#    -calc level 0 ridge...done (12ms)
#  block [99] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#  block [100] : 100 snps  (2ms)
#    -residualizing and scaling genotypes...done (2ms)
#    -calc working matrices...done (10ms)
#    -calc level 0 ridge...done (12ms)
#
#  Level 1 ridge...
#    -on phenotype 1 (projection_001)...done (399ms)
#    -on phenotype 2 (projection_002)...done (388ms)
#    -on phenotype 3 (projection_003)...done (393ms)
#    -on phenotype 4 (projection_004)...done (396ms)
#    -on phenotype 5 (projection_005)...done (395ms)
#    -on phenotype 6 (projection_006)...done (386ms)
#    -on phenotype 7 (projection_007)...done (391ms)
#    -on phenotype 8 (projection_008)...done (389ms)
#    -on phenotype 9 (projection_009)...done (372ms)
#    -on phenotype 10 (projection_010)...done (375ms)
#
# Output
# ------
# phenotype 1 (projection_001) :
#   0.01  : Rsq = 0.232675, MSE = 0.830827
#   0.25  : Rsq = 0.23125, MSE = 0.768306<- min value
#   0.5   : Rsq = 0.231256, MSE = 0.768541
#   0.75  : Rsq = 0.231086, MSE = 0.768912
#   0.99  : Rsq = 0.224679, MSE = 0.776638
#   * making predictions...writing LOCO predictions...done (64ms)
#
# phenotype 2 (projection_002) :
#   0.01  : Rsq = 0.273858, MSE = 0.805263
#   0.25  : Rsq = 0.272757, MSE = 0.726813<- min value
#   0.5   : Rsq = 0.272647, MSE = 0.727185
#   0.75  : Rsq = 0.272254, MSE = 0.727807
#   0.99  : Rsq = 0.265577, MSE = 0.73563
#   * making predictions...writing LOCO predictions...done (63ms)
#
# phenotype 3 (projection_003) :
#   0.01  : Rsq = 0.254056, MSE = 0.818159
#   0.25  : Rsq = 0.25341, MSE = 0.746145
#   0.5   : Rsq = 0.253723, MSE = 0.746028
#   0.75  : Rsq = 0.254205, MSE = 0.74571<- min value
#   0.99  : Rsq = 0.249909, MSE = 0.751004
#   * making predictions...writing LOCO predictions...done (62ms)
#
# phenotype 4 (projection_004) :
#   0.01  : Rsq = 0.328904, MSE = 0.767533
#   0.25  : Rsq = 0.329779, MSE = 0.66986
#   0.5   : Rsq = 0.329967, MSE = 0.669696
#   0.75  : Rsq = 0.33014, MSE = 0.669644<- min value
#   0.99  : Rsq = 0.325516, MSE = 0.67488
#   * making predictions...writing LOCO predictions...done (62ms)
#
# phenotype 5 (projection_005) :
#   0.01  : Rsq = 0.191626, MSE = 0.859852
#   0.25  : Rsq = 0.190558, MSE = 0.809046
#   0.5   : Rsq = 0.190825, MSE = 0.8091
#   0.75  : Rsq = 0.191215, MSE = 0.808912<- min value
#   0.99  : Rsq = 0.186936, MSE = 0.814511
#   * making predictions...writing LOCO predictions...done (62ms)
#
# phenotype 6 (projection_006) :
#   0.01  : Rsq = 0.165066, MSE = 0.880383
#   0.25  : Rsq = 0.164387, MSE = 0.835232
#   0.5   : Rsq = 0.16483, MSE = 0.835121
#   0.75  : Rsq = 0.165544, MSE = 0.8346<- min value
#   0.99  : Rsq = 0.16179, MSE = 0.839942
#   * making predictions...writing LOCO predictions...done (62ms)
#
# phenotype 7 (projection_007) :
#   0.01  : Rsq = 0.18314, MSE = 0.866872
#   0.25  : Rsq = 0.181894, MSE = 0.817709<- min value
#   0.5   : Rsq = 0.181933, MSE = 0.818005
#   0.75  : Rsq = 0.181807, MSE = 0.818366
#   0.99  : Rsq = 0.175493, MSE = 0.826284
#   * making predictions...writing LOCO predictions...done (62ms)
#
# phenotype 8 (projection_008) :
#   0.01  : Rsq = 0.288633, MSE = 0.794672
#   0.25  : Rsq = 0.288217, MSE = 0.711359<- min value
#   0.5   : Rsq = 0.288224, MSE = 0.711494
#   0.75  : Rsq = 0.288088, MSE = 0.711803
#   0.99  : Rsq = 0.282536, MSE = 0.718256
#   * making predictions...writing LOCO predictions...done (62ms)
#
# phenotype 9 (projection_009) :
#   0.01  : Rsq = 0.334404, MSE = 0.763088
#   0.25  : Rsq = 0.33416, MSE = 0.665452
#   0.5   : Rsq = 0.334427, MSE = 0.665296
#   0.75  : Rsq = 0.334825, MSE = 0.665052<- min value
#   0.99  : Rsq = 0.330771, MSE = 0.669837
#   * making predictions...writing LOCO predictions...done (63ms)
#
# phenotype 10 (projection_010) :
#   0.01  : Rsq = 0.143824, MSE = 0.893287
#   0.25  : Rsq = 0.142443, MSE = 0.857212
#   0.5   : Rsq = 0.142772, MSE = 0.85721
#   0.75  : Rsq = 0.143311, MSE = 0.856865<- min value
#   0.99  : Rsq = 0.139484, MSE = 0.862393
#   * making predictions...writing LOCO predictions...done (62ms)
#
# List of blup files written to: [data/gwas/regenie/projections/result_pred.list]
#
# Elapsed time : 7.89208s
# End time: Thu Nov 14 00:46:33 2024

# %%
command = """
docker run \
    -v ./data:/data -w / \
    ghcr.io/rgcgithub/regenie/regenie:v4.0.gz regenie \
    --step 2 \
    --bed data/simulated-phenotypes/Genotypes \
    --covarFile data/simulated-phenotypes/Covs_plink.txt \
    --phenoFile data/projected-phenotypes/phenotypes.tsv \
    --bsize 100 \
    --qt \
    --pred data/gwas/regenie/projections/result_pred.list \
    --out data/gwas/regenie/projections/result
"""
result = subprocess.run(shlex.split(command))
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# Start time: Thu Nov 14 00:46:33 2024
#
#               |===========================|
#               |      REGENIE v4.0.gz      |
#               |===========================|
#
# Copyright (c) 2020-2024 Joelle Mbatchou, Andrey Ziyatdinov and Jonathan Marchini.
# Distributed under the MIT License.
# Compiled with Boost Iostream library.
# Compiled with HTSlib.
# Using Intel MKL with Eigen.
#
# Log of output saved in file : data/gwas/regenie/projections/result.log
#
# Options in effect:
#   --step 2 \
#   --bed data/simulated-phenotypes/Genotypes \
#   --covarFile data/simulated-phenotypes/Covs_plink.txt \
#   --phenoFile data/projected-phenotypes/phenotypes.tsv \
#   --bsize 100 \
#   --qt \
#   --pred data/gwas/regenie/projections/result_pred.list \
#   --out data/gwas/regenie/projections/result
#
# Association testing mode with fast multithreading using OpenMP
#  * bim              : [data/simulated-phenotypes/Genotypes.bim] n_snps = 10000
#  * fam              : [data/simulated-phenotypes/Genotypes.fam] n_samples = 10000
#  * bed              : [data/simulated-phenotypes/Genotypes.bed]
#  * phenotypes       : [data/projected-phenotypes/phenotypes.tsv] n_pheno = 10
#    -number of phenotyped individuals  = 10000
#  * covariates       : [data/simulated-phenotypes/Covs_plink.txt] n_cov = 5
#    -number of individuals with covariate data = 10000
#  * number of individuals used in analysis = 10000
#  * number of observations for each trait:
#    - 'projection_001': 10000 observations
#    - 'projection_002': 10000 observations
#    - 'projection_003': 10000 observations
#    - 'projection_004': 10000 observations
#    - 'projection_005': 10000 observations
#    - 'projection_006': 10000 observations
#    - 'projection_007': 10000 observations
#    - 'projection_008': 10000 observations
#    - 'projection_009': 10000 observations
#    - 'projection_010': 10000 observations
#  * LOCO predictions : [data/gwas/regenie/projections/result_pred.list]
#    -file [/data/gwas/regenie/projections/result_1.loco] for phenotype 'projection_001'
#    -file [/data/gwas/regenie/projections/result_2.loco] for phenotype 'projection_002'
#    -file [/data/gwas/regenie/projections/result_3.loco] for phenotype 'projection_003'
#    -file [/data/gwas/regenie/projections/result_4.loco] for phenotype 'projection_004'
#    -file [/data/gwas/regenie/projections/result_5.loco] for phenotype 'projection_005'
#    -file [/data/gwas/regenie/projections/result_6.loco] for phenotype 'projection_006'
#    -file [/data/gwas/regenie/projections/result_7.loco] for phenotype 'projection_007'
#    -file [/data/gwas/regenie/projections/result_8.loco] for phenotype 'projection_008'
#    -file [/data/gwas/regenie/projections/result_9.loco] for phenotype 'projection_009'
#    -file [/data/gwas/regenie/projections/result_10.loco] for phenotype 'projection_010'
#    -residualizing and scaling phenotypes...done (1ms)
#  * # threads        : [15]
#  * block size       : [100]
#  * # blocks         : [100]
#  * approximate memory usage : 22MB
#  * using minimum MAC of 5 (variants with lower MAC are ignored)
#
# Chromosome 1 [100 blocks in total]
#    -reading loco predictions for the chromosome...done (199ms)
#  block [1/100] : done (75ms)
#  block [2/100] : done (6ms)
#  block [3/100] : done (5ms)
#  block [4/100] : done (5ms)
#  block [5/100] : done (5ms)
#  block [6/100] : done (5ms)
#  block [7/100] : done (5ms)
#  block [8/100] : done (5ms)
#  block [9/100] : done (5ms)
#  block [10/100] : done (5ms)
#  block [11/100] : done (5ms)
#  block [12/100] : done (5ms)
#  block [13/100] : done (5ms)
#  block [14/100] : done (5ms)
#  block [15/100] : done (5ms)
#  block [16/100] : done (5ms)
#  block [17/100] : done (5ms)
#  block [18/100] : done (5ms)
#  block [19/100] : done (5ms)
#  block [20/100] : done (5ms)
#  block [21/100] : done (5ms)
#  block [22/100] : done (5ms)
#  block [23/100] : done (5ms)
#  block [24/100] : done (5ms)
#  block [25/100] : done (5ms)
#  block [26/100] : done (5ms)
#  block [27/100] : done (5ms)
#  block [28/100] : done (5ms)
#  block [29/100] : done (5ms)
#  block [30/100] : done (5ms)
#  block [31/100] : done (5ms)
#  block [32/100] : done (5ms)
#  block [33/100] : done (5ms)
#  block [34/100] : done (5ms)
#  block [35/100] : done (5ms)
#  block [36/100] : done (5ms)
#  block [37/100] : done (5ms)
#  block [38/100] : done (5ms)
#  block [39/100] : done (5ms)
#  block [40/100] : done (5ms)
#  block [41/100] : done (5ms)
#  block [42/100] : done (5ms)
#  block [43/100] : done (5ms)
#  block [44/100] : done (5ms)
#  block [45/100] : done (5ms)
#  block [46/100] : done (5ms)
#  block [47/100] : done (5ms)
#  block [48/100] : done (5ms)
#  block [49/100] : done (5ms)
#  block [50/100] : done (5ms)
#  block [51/100] : done (5ms)
#  block [52/100] : done (5ms)
#  block [53/100] : done (5ms)
#  block [54/100] : done (5ms)
#  block [55/100] : done (5ms)
#  block [56/100] : done (5ms)
#  block [57/100] : done (5ms)
#  block [58/100] : done (5ms)
#  block [59/100] : done (5ms)
#  block [60/100] : done (5ms)
#  block [61/100] : done (5ms)
#  block [62/100] : done (5ms)
#  block [63/100] : done (5ms)
#  block [64/100] : done (5ms)
#  block [65/100] : done (5ms)
#  block [66/100] : done (5ms)
#  block [67/100] : done (5ms)
#  block [68/100] : done (5ms)
#  block [69/100] : done (5ms)
#  block [70/100] : done (5ms)
#  block [71/100] : done (5ms)
#  block [72/100] : done (5ms)
#  block [73/100] : done (5ms)
#  block [74/100] : done (5ms)
#  block [75/100] : done (5ms)
#  block [76/100] : done (5ms)
#  block [77/100] : done (5ms)
#  block [78/100] : done (5ms)
#  block [79/100] : done (5ms)
#  block [80/100] : done (5ms)
#  block [81/100] : done (5ms)
#  block [82/100] : done (5ms)
#  block [83/100] : done (5ms)
#  block [84/100] : done (5ms)
#  block [85/100] : done (5ms)
#  block [86/100] : done (5ms)
#  block [87/100] : done (5ms)
#  block [88/100] : done (5ms)
#  block [89/100] : done (5ms)
#  block [90/100] : done (5ms)
#  block [91/100] : done (5ms)
#  block [92/100] : done (5ms)
#  block [93/100] : done (5ms)
#  block [94/100] : done (5ms)
#  block [95/100] : done (5ms)
#  block [96/100] : done (5ms)
#  block [97/100] : done (5ms)
#  block [98/100] : done (5ms)
#  block [99/100] : done (5ms)
#  block [100/100] : done (5ms)
#
# Association results stored separately for each trait in files :
# * [data/gwas/regenie/projections/result_projection_001.regenie]
# * [data/gwas/regenie/projections/result_projection_002.regenie]
# * [data/gwas/regenie/projections/result_projection_003.regenie]
# * [data/gwas/regenie/projections/result_projection_004.regenie]
# * [data/gwas/regenie/projections/result_projection_005.regenie]
# * [data/gwas/regenie/projections/result_projection_006.regenie]
# * [data/gwas/regenie/projections/result_projection_007.regenie]
# * [data/gwas/regenie/projections/result_projection_008.regenie]
# * [data/gwas/regenie/projections/result_projection_009.regenie]
# * [data/gwas/regenie/projections/result_projection_010.regenie]
#
# Number of ignored tests due to low MAC : 0
#
# Elapsed time : 1.55593s
# End time: Thu Nov 14 00:46:35 2024

# %% [markdown]
# ## SAIGE
#
# ### Features

# %%
command_template = Template("""
docker run \
    -v ./data:/data -w / \
    wzhou88/saige:1.3.0 step1_fitNULLGLMM.R \
    --plinkFile=data/simulated-phenotypes/Genotypes \
    --useSparseGRMtoFitNULL=FALSE \
    --covarColList=sharedConfounder_norm1,sharedConfounder_norm2,sharedConfounder_norm3,independentConfounder_norm1,independentConfounder_norm2 \
    --sampleIDColinphenoFile=IID \
    --invNormalize=TRUE \
    --traitType=quantitative \
    --nThreads=16 \
    --IsOverwriteVarianceRatioFile=TRUE \
    --phenoCol=$PHENOTYPE \
    --phenoFile=data/simulated-phenotypes/Ysim_saige.txt \
    --outputPrefix=data/gwas/saige/features/$PHENOTYPE
""")

for feature_idx in tqdm.tnrange(1, n_features + 1):
    command = command_template.substitute(PHENOTYPE=f"feature_{feature_idx:02}")
    result = subprocess.run(shlex.split(command), capture_output=True)
    result.check_returncode()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
command_template = Template("""
docker run \
    -v ./data:/data -w / \
    wzhou88/saige:1.3.0 step2_SPAtests.R \
    --bedFile=data/simulated-phenotypes/Genotypes.bed \
    --bimFile=data/simulated-phenotypes/Genotypes.bim \
    --famFile=data/simulated-phenotypes/Genotypes.fam \
    --LOCO=FALSE \
    --GMMATmodelFile=data/gwas/saige/features/$PHENOTYPE.rda \
    --varianceRatioFile=data/gwas/saige/features/$PHENOTYPE.varianceRatio.txt \
    --SAIGEOutputFile=data/gwas/saige/features/$PHENOTYPE.txt
""")

for feature_idx in tqdm.tnrange(1, n_features + 1):
    command = command_template.substitute(PHENOTYPE=f"feature_{feature_idx:02}")
    result = subprocess.run(shlex.split(command), capture_output=True)
    try:
        result.check_returncode()
    except Exception as e:
        print(result.stderr.decode())
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### Projections

# %%
command_template = Template("""
docker run \
    -v ./data:/data -w / \
    wzhou88/saige:1.3.0 step1_fitNULLGLMM.R \
    --plinkFile=data/simulated-phenotypes/Genotypes \
    --useSparseGRMtoFitNULL=FALSE \
    --covarColList=sharedConfounder_norm1,sharedConfounder_norm2,sharedConfounder_norm3,independentConfounder_norm1,independentConfounder_norm2 \
    --sampleIDColinphenoFile=IID \
    --invNormalize=TRUE \
    --traitType=quantitative \
    --nThreads=16 \
    --IsOverwriteVarianceRatioFile=TRUE \
    --phenoCol=$PHENOTYPE \
    --phenoFile=data/projected-phenotypes/phenotypes_saige.tsv \
    --outputPrefix=data/gwas/saige/projections/$PHENOTYPE
""")

for projection_idx in tqdm.tnrange(1, n_projections + 1):
    command = command_template.substitute(PHENOTYPE=f"projection_{projection_idx:03}")
    result = subprocess.run(shlex.split(command), capture_output=True)
    try:
        result.check_returncode()
    except Exception as e:
        print(result.stderr.decode())
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# Loading required package: optparse
# Error in glmmkin.ai_PCG_Rcpp_Quantitative(bedFile, bimFile, famFile, Xorig,  :
#   ERROR! The first variance component parameter estimate is 0
# Calls: fitNULLGLMM -> system.time -> glmmkin.ai_PCG_Rcpp_Quantitative
# Timing stopped at: 10.55 0.107 1.695
# Execution halted

# %%
command_template = Template("""
docker run \
    -v ./data:/data -w / \
    wzhou88/saige:1.3.0 step2_SPAtests.R \
    --bedFile=data/simulated-phenotypes/Genotypes.bed \
    --bimFile=data/simulated-phenotypes/Genotypes.bim \
    --famFile=data/simulated-phenotypes/Genotypes.fam \
    --LOCO=FALSE \
    --GMMATmodelFile=data/gwas/saige/projections/$PHENOTYPE.rda \
    --varianceRatioFile=data/gwas/saige/projections/$PHENOTYPE.varianceRatio.txt \
    --SAIGEOutputFile=data/gwas/saige/projections/$PHENOTYPE.txt
""")

for projection_idx in tqdm.tnrange(1, n_projections + 1):
    command = command_template.substitute(PHENOTYPE=f"projection_{projection_idx:03}")
    result = subprocess.run(shlex.split(command), capture_output=True)
    try:
        result.check_returncode()
    except Exception as e:
        print(result.stderr.decode())
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# Loading required package: RhpcBLASctl
# Error in load(GMMATmodelFile) : empty (zero-byte) input file
# Calls: SPAGMMATtest -> ReadModel -> load
# Execution halted

# %% [markdown]
# ## FastGWA
#
# ### Features

# %%
command_template = Template("""
gcta64 \
    --bfile data/simulated-phenotypes/Genotypes \
    --grm-sparse data/grm/gcta-sparse \
    --pheno data/simulated-phenotypes/Ysim_plink.txt \
    --mpheno $mpheno \
    --qcovar data/simulated-phenotypes/Covs_plink.txt \
    --fastGWA-mlm \
    --thread-num 16 \
    --est-vg HE \
    --save-fastGWA-mlm-residual \
    --out data/gwas/fastgwa/features/result_$mpheno
""")

for feature_idx in tqdm.tnrange(1, n_features + 1):
    command = command_template.substitute(mpheno=feature_idx)
    result = subprocess.run(shlex.split(command), capture_output=True)
    result.check_returncode()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### Projections

# %%
command_template = Template("""
gcta64 \
    --bfile data/simulated-phenotypes/Genotypes \
    --grm-sparse data/grm/gcta-sparse \
    --pheno data/projected-phenotypes/phenotypes.tsv \
    --mpheno $mpheno \
    --qcovar data/simulated-phenotypes/Covs_plink.txt \
    --fastGWA-mlm \
    --thread-num 16 \
    --est-vg HE \
    --save-fastGWA-mlm-residual \
    --out data/gwas/fastgwa/projections/result_$mpheno
""")

for feature_idx in tqdm.tnrange(1, n_projections + 1):
    command = command_template.substitute(mpheno=feature_idx)
    result = subprocess.run(shlex.split(command), capture_output=True)
    result.check_returncode()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
